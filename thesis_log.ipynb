# %% [markdown]
# # Thesis Log
#
# ## Pre Log
#
# Made scripts up to compiling vcf to `make_bam`. Cannot get BAMs to generate. Possible issue with conda and modules.
#
# VB21036 likely has sequence contamination from lookig at GC content.
#
# ## Week 3
# #### Mon 11th May
#
# Made git hub repo. Added scripts into repo. Redefined paths to be absolute. Cloned it into ada.
#
# Fix `make_bam`. Samtools, and picard need to be called by the SLURM module. Not in the conda env. Made the BAMs
#
# #### Tue 12th May
#
# Fixed and ran VCF script.
#
# Made script `high_GC` to filter reads with GC% > 65 from VB21036.
#
# #### Wed 13th May
#
# Merged VCFs. Got GC filtering script to work and produce a fasta file. Created VCF filter and fst scan scripts.
#
# #### Thu 14th May
#
# Running GC filter, and VCF filter.

# %% [markdown]
# ## Week 4
# #### Mon 18th May
#
# Ran FST script. Started doing GWAS. Finding a way to look at alignment as only 4 chromosomes were present on the FST.
#
# A few spikes were present but none were really distinct.
#
# #### Tue 19th May
#
# Downloaded high GC (65-75) reads from the sample which failed and blasted them. Downloaded BAM files to check coverage.
#
# Identfied potential bacteria: *Kocuria rhizophila*
#
# Attempted less stringent filters for the FST and GWAS. Had no effect on FST results
#
# #### Wed 20th May
#
# Ran the FST scan on the unfiltered VCF. Aim to see if the chromsomes are being filtered out.
#
# Remade chr_list with all sequences in it.
#
# Going to remake BAMS, using the alternate haplotype reference to see.
#
# Lack of chromosome was from incomplete VCF merging, given more tiem to the script to run.
#
# #### Thu 21st May

# %% [markdown]
# ## Week 5
# #### Tue 26th May
# Trying alternate FST window sizes. Testing 1000, 1250, and 1500.
#
# Using 1000 as a start to identify genes using bedtools.
#
# Converted GBFF annotation file to GFF3. Extracted genes from the GFF3 file which are within the windows from the FST plot. Produced a GFF3 file with just the genes from the high FST regions. Unable to get it to contain the correct annotations.
#
# #### Wed 27th May
#
# Produced a FATSA with the regions with high FST. Got the fasta file, but BLAST of some sequences did not return useful regions.
#
# Errors been happening as GBFF file does not contain annotations. Need to annotate the reference to be able to do this.
#
# #### Thu 28th May
#
# Going to annotate the reference genome. Attempting to use MAKER, Eukan, and BRAKER. Trying to install helixer.
#
# #### Fri 29th May
#
# Further planning of introduction.
#
# Made a script utilising Helixer. Uses deep learning algorithms to annotate the genome. Depends on hdf5 and HelixerPost. Unsure on the quality of the annotation but we will see.
# Other annotataion tools (MAKER, Eukan, and BRAKER) required additional information about the genomes which we don't have.

# %% [markdown]
# ## Tools used
#
# | Tool name   | Version  | Link |
# |-------------|----------|------|
# | FastQC      | 0.12.1   | https://github.com/s-andrews/FastQC |
# | multiqc     | 1.0.dev0 | https://github.com/MultiQC/MultiQC |
# | fastp       | 0.23.4   | https://github.com/opengene/fastpbwa |
# | bwa         | 0.7.19   | https://github.com/lh3/BWA |
# | samtools    | 1.18     | https://github.com/samtools/samtools |
# | picard      | 3.0.0    | https://github.com/broadinstitute/picard |
# | bcftools    | 1.19     | https://github.com/samtools/bcftools |
# | seqkit      | 2.13.0   | https://github.com/shenwei356/seqkit |
# | biopython   | 1.87     | https://github.com/biopython/biopython |
# | plink       | 1.90b7.7 | https://github.com/chrchang/plink-ng |
# | bedtools    | 2.31.0   | https://github.com/arq5x/bedtools2 |
# | Helixer     | 0.3.6    | https://github.com/usadellab/Helixer |
# | HelixerPost | 0.3.0    | https://github.com/usadellab/HelixerPost |
# | hdf5        | 1.12.2   | https://github.com/HDFGroup/hdf5 |
